# %% [markdown]
# <a href="https://colab.research.google.com/github/dkaratzas/DL2022-23/blob/main/Problems%208%20-%20RNNs/P8_RNNs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/dkaratzas/DL2022-23/blob/main/Problems%208%20-%20RNNs/P8_RNNs.ipynb)

# %% [markdown]
# # Text generation with an RNN
#
# In this notebook we will learn how to generate text with a Recurrent Neural Network.
#
# We will work with a dataset of Shakespeare's writing from Andrej Karpathy's article [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/).
#
# Given a sequence of characters from this data (for example "Shakespear"), we will train a model to predict the next character in the sequence ("e"). Longer sequences of text can be generated by calling the model repeatedly.

# %% [markdown]
# ### Import the necessary modules

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import TensorDataset, DataLoader

import matplotlib.pyplot as plt
from collections import Counter
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
# Out:
# PyTorch Version:  2.0.0+cu118

# %%
#If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

#  use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Download the Shakespeare dataset

# %%
! wget https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# Out:
# --2023-04-25 21:28:30--  https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.128, 74.125.195.128, 172.253.117.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘shakespeare.txt.3’
#
# shakespeare.txt.3   100%[===================>]   1.06M  --.-KB/s    in 0.01s
#
# 2023-04-25 21:28:30 (103 MB/s) - ‘shakespeare.txt.3’ saved [1115394/1115394]

# %% [markdown]
# ###  Create a dataset class
#
# For training we need a dataset of (input, label) pairs. Where input and label are sequences of characters. At each time step the input is the current character and the label is the next character. For example:
#
# ```
# input = ['S', 'h', 'a', 'k', 'e', 's', 'p', 'e', 'a', 'r']
# label = ['h', 'a', 'k', 'e', 's', 'p', 'e', 'a', 'r', 'e']
#  ```
#
# Actually we will vectorize the characters to convert them into numerical values.
#
# ```
# input = [44, 7, 0, 10, 4, 18, 15, 4, 0, 17]
# label = [7, 0, 10, 4, 18, 15, 4, 0, 17, 4]
# ```
#
# where each integer value is a class label, and the number of classes is the number of unique characters in our training data (our vocabulary size).

# %%
class DatasetFromTextFile():
    def __init__(self, filename, sequence_length):
        self.filename = filename
        self.sequence_length = sequence_length
        
        # The whole sequence of characters in the text file (including characters like the end of line character '\n', punctuation marks, etc.)
        self.chars = self.load_chars()
        # The list of unique characters (our vocabulary)
        self.uniq_chars = self.get_uniq_chars()

        # A dictionary with indices as keys and characters as values
        self.index_to_char = {index: char for index, char in enumerate(self.uniq_chars)}
        # A dictionary with characters as keys and indices as values
        self.char_to_index = {char: index for index, char in enumerate(self.uniq_chars)}

        # The whole sequence of character indexes
        # We want to vectorize our text using one-hot vectors at character level
        # But instead of using the one-hot vector we just keep the index of the 1 value
        self.chars_indices = [self.char_to_index[w] for w in self.chars]

        # Split the sequence into chunks of `sequence_length` characters
        # `x` is the input to the model and `y` is the output of the model
        # `y` is the same seuqence as `x` but one character shifted to the right.
        self.x, self.y = self.get_data()

    def load_chars(self):
        with open(self.filename) as fp:
            text = fp.read()
        print(f'Length of text: {len(text)} characters')
        return text

    def get_uniq_chars(self):
        char_counts = Counter(self.chars)
        uniq_chars = sorted(char_counts, key=char_counts.get, reverse=True)
        print(f'Unique characters (vocabulary size): {len(uniq_chars)}')
        return uniq_chars

    def get_data(self):
        x,y = [], []
        for index in range(0, len(self.chars_indices)-self.sequence_length, self.sequence_length):
            x.append(np.array(self.chars_indices[index:index+self.sequence_length]))
            y.append(np.array(self.chars_indices[index+1:index+self.sequence_length+1]))
        
        return  torch.from_numpy(np.array(x)), torch.from_numpy(np.array(y)).long()
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        assert ((idx >= 0) & (idx < len(self.y))), "Dataset index out of range"
        return self.x[idx], self.y[idx]

# %%
# Create the dataset
sequence_length = 100
ShakespeareDataset = DatasetFromTextFile('shakespeare.txt', sequence_length)

print(f'We have {ShakespeareDataset.x.shape[0]} input sequence samples of length {ShakespeareDataset.x.shape[1]} \
and {ShakespeareDataset.y.shape[0]} label sequences of length {ShakespeareDataset.y.shape[1]}')

# Create the Torch DataLoader
batch_size = 64
train_loader = DataLoader(ShakespeareDataset, shuffle=True, batch_size=batch_size, drop_last=True)
# Out:
# Length of text: 1115394 characters
# Unique characters (vocabulary size): 65
# We have 11153 input sequence samples of length 100 and 11153 label sequences of length 100

# %% [markdown]
# ## Build the model
#
# Our model has three layers:
#
# * `torch.nn.Embedding`: The input layer. A trainable lookup table that will map each character-ID (class ID) to a dense vector with `embedding_dim` dimensions;
# * `torch.nn.GRU`: A type of RNN with `hidden_dim` units
# * `torch.nn.Linear`: The output layer, with number of outputs as our vocabulary size (`len(dataset.uniq_chars)`). It outputs one logit for each character in the vocabulary. These are the log-likelihood of each character according to the model.

# %% [markdown]
# For each character the model looks up the embedding, runs the GRU one timestep with the embedding as input, and applies the dense layer to generate logits predicting the log-likelihood of the next character:
#
# ![text_generation_training.png](data:image/png;base64,...)
#
# Image source: http://www.tensorflow.org

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 1:** Complete the code of the `Model` class. You need to embed your input using an `nn.Embedding` layer, create a GRU with `n_layers`, and then compute the output logits.
#
# </span>

# %%
class Model(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.2):
        super(Model, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers
        
        # YOUR CODE HERE
        self.embedding = nn.Embedding(input_dim, embedding_dim) 
        self.gru = nn.GRU(input_size = embedding_dim, hidden_size = hidden_dim, num_layers = n_layers, dropout=drop_prob, batch_first=True) #IMPORANT TO SET BATCH FIRST TO TRUE TO TELL THAT IS THE FIRDT DIMENSION
        self.fc = nn.Linear(in_features = hidden_dim, out_features = output_dim)
        
        
    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.gru(emb, h)
        out = self.fc(out)
        return out, h
    
    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        hidden = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return hidden

# %% [markdown]
# Now we can instantiate the model as follows:

# %%
input_dim = len(ShakespeareDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(ShakespeareDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

model_gru = Model(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(model_gru)
# Out:
# Model(
#   (embedding): Embedding(65, 300)
#   (gru): GRU(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )

# %% [markdown]
# ## Quick Experiment

# %% [markdown]
# Let's create a string and pass it through our model

# %%
data = torch.tensor([ShakespeareDataset.char_to_index[w] for w in "Hello"])
print(data.shape)
# Out:
# torch.Size([5])

# %% [markdown]
# Our model expects a batch. We will create a batch of 1, using this one data point we have created

# %%
data = data.unsqueeze(0) # this adds one more dimension (the batch one) to our data
print(data.shape)
# Out:
# torch.Size([1, 5])

# %% [markdown]
# Time to pass this through our model. To do so, we need to (1) move our data to the same device like the model and (2) initialise the state of our RNN

# %%
data = data.to(device)
state = model_gru.init_hidden(batch_size = 1) # remember that we will use just a single data point jere
state = state.to(device)
out, state = model_gru(data, state) # The forward pass expects the current state as an argument, and returns the updated state in the output

print(out.shape)
# Out:
# torch.Size([1, 5, 65])

# %% [markdown]
# Our output returns 65 probability values for each character... We need to find which one is the maximum probability for each position, and convert it to the corresponding character

# %%
_, idxs = torch.max(out[0], dim = 1)

print([ShakespeareDataset.index_to_char[int(c)] for c in idxs])
# Out:
# ['i', 'b', '.', '.', '.']

# %% [markdown]
# As expected both inputs and outputs have the same shape, and the predicted characters are just random since the model is not trained yet.

# %% [markdown]
# ## Train the model
#
# Training a language model is essentially a classification problem. Given the previous RNN state, and the input character at this time step, predict the class of the next character.
#
# <span style="color:blue">
#
# **Exercise 2:** which loss function do you think we shall use to train our model?
#
# </span>

# %%
def train(dataloader, model, batch_size, sequence_length, num_epochs):
    model.train()

    criterion =  nn.CrossEntropyLoss() #CODE HERE
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    losses = []
    for epoch in range(num_epochs):

        for batch, (x, y) in enumerate(dataloader):
            state = model.init_hidden(batch_size) # Start with a new state in each batch            
            state = state.to(device)
            
            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            
            y_pred, state = model(x, state)
            loss = criterion(y_pred.transpose(1, 2), y)

            loss.backward()
            optimizer.step()

            if batch%30 == 0:
                print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
                losses.append(loss.item())
    return losses

# %% [markdown]
# Now train the model for 20 epochs and visualize the training loss curve.

# %%
num_epochs = 20

losses = train(train_loader, model_gru, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.177859306335449}
# {'epoch': 0, 'batch': 30, 'loss': 2.256964921951294}
# {'epoch': 0, 'batch': 60, 'loss': 1.9751659631729126}
# {'epoch': 0, 'batch': 90, 'loss': 1.800825595855713}
# {'epoch': 0, 'batch': 120, 'loss': 1.715366244316101}
# {'epoch': 0, 'batch': 150, 'loss': 1.6145567893981934}
# {'epoch': 1, 'batch': 0, 'loss': 1.557725191116333}
# {'epoch': 1, 'batch': 30, 'loss': 1.5348858833312988}
# {'epoch': 1, 'batch': 60, 'loss': 1.5235927104949951}
# {'epoch': 1, 'batch': 90, 'loss': 1.4688916206359863}
# {'epoch': 1, 'batch': 120, 'loss': 1.4185991287231445}
# {'epoch': 1, 'batch': 150, 'loss': 1.413665771484375}
# {'epoch': 2, 'batch': 0, 'loss': 1.3723227977752686}
# {'epoch': 2, 'batch': 30, 'loss': 1.4098381996154785}
# {'epoch': 2, 'batch': 60, 'loss': 1.3971251249313354}
# {'epoch': 2, 'batch': 90, 'loss': 1.359655499458313}
# {'epoch': 2, 'batch': 120, 'loss': 1.3714169263839722}
# {'epoch': 2, 'batch': 150, 'loss': 1.3974931240081787}
# {'epoch': 3, 'batch': 0, 'loss': 1.3216907978057861}
# {'epoch': 3, 'batch': 30, 'loss': 1.2920312881469727}
# {'epoch': 3, 'batch': 60, 'loss': 1.3145800828933716}
# {'epoch': 3, 'batch': 90, 'loss': 1.3109022378921509}
# {'epoch': 3, 'batch': 120, 'loss': 1.3108288049697876}
# {'epoch': 3, 'batch': 150, 'loss': 1.3099116086959839}
# {'epoch': 4, 'batch': 0, 'loss': 1.2892690896987915}
# {'epoch': 4, 'batch': 30, 'loss': 1.245388150215149}
# {'epoch': 4, 'batch': 60, 'loss': 1.2397959232330322}
# {'epoch': 4, 'batch': 90, 'loss': 1.2522460222244263}
# {'epoch': 4, 'batch': 120, 'loss': 1.22771418094635}
# {'epoch': 4, 'batch': 150, 'loss': 1.282026767730713}
# {'epoch': 5, 'batch': 0, 'loss': 1.2280375957489014}
# {'epoch': 5, 'batch': 30, 'loss': 1.2242034673690796}
# {'epoch': 5, 'batch': 60, 'loss': 1.230992317199707}
# {'epoch': 5, 'batch': 90, 'loss': 1.2522222995758057}
# {'epoch': 5, 'batch': 120, 'loss': 1.2122443914413452}
# {'epoch': 5, 'batch': 150, 'loss': 1.2107938528060913}
# {'epoch': 6, 'batch': 0, 'loss': 1.180195927619934}
# {'epoch': 6, 'batch': 30, 'loss': 1.1890387535095215}
# {'epoch': 6, 'batch': 60, 'loss': 1.2103358507156372}
# {'epoch': 6, 'batch': 90, 'loss': 1.1812607049942017}
# {'epoch': 6, 'batch': 120, 'loss': 1.2006007432937622}
# {'epoch': 6, 'batch': 150, 'loss': 1.2341945171356201}
# {'epoch': 7, 'batch': 0, 'loss': 1.1349982023239136}
# {'epoch': 7, 'batch': 30, 'loss': 1.1543526649475098}
# {'epoch': 7, 'batch': 60, 'loss': 1.146236777305603}
# {'epoch': 7, 'batch': 90, 'loss': 1.1723183393478394}
# {'epoch': 7, 'batch': 120, 'loss': 1.1815513372421265}
# {'epoch': 7, 'batch': 150, 'loss': 1.2012813091278076}
# {'epoch': 8, 'batch': 0, 'loss': 1.102231740951538}
# {'epoch': 8, 'batch': 30, 'loss': 1.0927983522415161}
# {'epoch': 8, 'batch': 60, 'loss': 1.0926235914230347}
# {'epoch': 8, 'batch': 90, 'loss': 1.097049593925476}
# {'epoch': 8, 'batch': 120, 'loss': 1.1433236598968506}
# {'epoch': 8, 'batch': 150, 'loss': 1.150245189666748}
# {'epoch': 9, 'batch': 0, 'loss': 1.049605369567871}
# {'epoch': 9, 'batch': 30, 'loss': 1.0782114267349243}
# {'epoch': 9, 'batch': 60, 'loss': 1.069492220878601}
# {'epoch': 9, 'batch': 90, 'loss': 1.0804753303527832}
# {'epoch': 9, 'batch': 120, 'loss': 1.1540662050247192}
# {'epoch': 9, 'batch': 150, 'loss': 1.0878252983093262}
# {'epoch': 10, 'batch': 0, 'loss': 1.0448212623596191}
# {'epoch': 10, 'batch': 30, 'loss': 1.0393245220184326}
# {'epoch': 10, 'batch': 60, 'loss': 1.0647666454315186}
# {'epoch': 10, 'batch': 90, 'loss': 1.0811539888381958}
# {'epoch': 10, 'batch': 120, 'loss': 1.0730804204940796}
# {'epoch': 10, 'batch': 150, 'loss': 1.0924776792526245}
# {'epoch': 11, 'batch': 0, 'loss': 1.0016528367996216}
# {'epoch': 11, 'batch': 30, 'loss': 0.9913330674171448}
# {'epoch': 11, 'batch': 60, 'loss': 1.0275722742080688}
# {'epoch': 11, 'batch': 90, 'loss': 1.0136266946792603}
# {'epoch': 11, 'batch': 120, 'loss': 1.027268409729004}
# {'epoch': 11, 'batch': 150, 'loss': 1.0905529260635376}
# {'epoch': 12, 'batch': 0, 'loss': 0.9857490658760071}
# {'epoch': 12, 'batch': 30, 'loss': 0.9648058414459229}
# {'epoch': 12, 'batch': 60, 'loss': 0.9916228652000427}
# {'epoch': 12, 'batch': 90, 'loss': 0.9824361205101013}
# {'epoch': 12, 'batch': 120, 'loss': 1.042789101600647}
# {'epoch': 12, 'batch': 150, 'loss': 1.0485281944274902}
# {'epoch': 13, 'batch': 0, 'loss': 0.9641302227973938}
# {'epoch': 13, 'batch': 30, 'loss': 0.957054078578949}
# {'epoch': 13, 'batch': 60, 'loss': 0.9568101763725281}
# {'epoch': 13, 'batch': 90, 'loss': 0.9835869073867798}
# {'epoch': 13, 'batch': 120, 'loss': 1.0113393068313599}
# {'epoch': 13, 'batch': 150, 'loss': 1.0303133726119995}
# {'epoch': 14, 'batch': 0, 'loss': 0.9187349081039429}
# {'epoch': 14, 'batch': 30, 'loss': 0.9282724857330322}
# {'epoch': 14, 'batch': 60, 'loss': 0.9368173480033875}
# {'epoch': 14, 'batch': 90, 'loss': 0.936382532119751}
# {'epoch': 14, 'batch': 120, 'loss': 0.9670224189758301}
# {'epoch': 14, 'batch': 150, 'loss': 1.0004762411117554}
# {'epoch': 15, 'batch': 0, 'loss': 0.8957377076148987}
# {'epoch': 15, 'batch': 30, 'loss': 0.9037484526634216}
# {'epoch': 15, 'batch': 60, 'loss': 0.929602861404419}
# {'epoch': 15, 'batch': 90, 'loss': 0.9199036359786987}
# {'epoch': 15, 'batch': 120, 'loss': 0.9723508358001709}
# {'epoch': 15, 'batch': 150, 'loss': 0.9637772440910339}
# {'epoch': 16, 'batch': 0, 'loss': 0.8801670670509338}
# {'epoch': 16, 'batch': 30, 'loss': 0.8692378997802734}
# {'epoch': 16, 'batch': 60, 'loss': 0.9241493344306946}
# {'epoch': 16, 'batch': 90, 'loss': 0.9526104927062988}
# {'epoch': 16, 'batch': 120, 'loss': 0.9504029750823975}
# {'epoch': 16, 'batch': 150, 'loss': 0.9333158135414124}
# {'epoch': 17, 'batch': 0, 'loss': 0.868675172328949}
# {'epoch': 17, 'batch': 30, 'loss': 0.8873686790466309}
# {'epoch': 17, 'batch': 60, 'loss': 0.8953588604927063}
# {'epoch': 17, 'batch': 90, 'loss': 0.8866543769836426}
# {'epoch': 17, 'batch': 120, 'loss': 0.9458544254302979}
# {'epoch': 17, 'batch': 150, 'loss': 0.9459590911865234}
# {'epoch': 18, 'batch': 0, 'loss': 0.8749195337295532}
# {'epoch': 18, 'batch': 30, 'loss': 0.8666360378265381}
# {'epoch': 18, 'batch': 60, 'loss': 0.895881175994873}
# {'epoch': 18, 'batch': 90, 'loss': 0.8838580250740051}
# {'epoch': 18, 'batch': 120, 'loss': 0.8780620694160461}
# {'epoch': 18, 'batch': 150, 'loss': 0.9378151893615723}
# {'epoch': 19, 'batch': 0, 'loss': 0.8458612561225891}
# {'epoch': 19, 'batch': 30, 'loss': 0.8186219930648804}
# {'epoch': 19, 'batch': 60, 'loss': 0.8890735507011414}
# {'epoch': 19, 'batch': 90, 'loss': 0.8928754925727844}
# {'epoch': 19, 'batch': 120, 'loss': 0.8832340240478516}
# {'epoch': 19, 'batch': 150, 'loss': 0.9072971343994141}

# %%
# Visualize the loss evolution during training
plt.plot(losses)
plt.title('model loss')
plt.show()

# %% [markdown]
# ## Try the trained model
#
# Let's try again to predict some characters given the input sentence 'ROMEO:'. Now the predicted characters should be much better.

# %%
with torch.no_grad():
    input_str = 'ROMEO:'

    state = model_gru.init_hidden(batch_size=1)
    state = state.to(device)
    data = torch.tensor([[ShakespeareDataset.char_to_index[char] for char in input_str]]).to(device)
    output, state = model_gru(data, state)

    _, predicted_idxs = torch.max(output[0], dim = 1)
    predicted_idxs = predicted_idxs.cpu().numpy()
    
    predicted_str = ''.join([ShakespeareDataset.index_to_char[idx] for idx in predicted_idxs])

    print(f'Input shape: {data.size()}')
    print(f'Output shape: {data.size()}')
    print(f'Input string: {input_str}')
    print(f'Output string: {predicted_str}')
# Out:
# Input shape: torch.Size([1, 6])
# Output shape: torch.Size([1, 6])
# Input string: ROMEO:
# Output string: DMEO:

# %% [markdown]
# ## Generate new text

# %%
def predict(dataset, model, text, next_chars=1000):
    model.eval()

    chars = [char for char in text]
    state = model.init_hidden(1)
    state = state.to(device)

    # we start by feeding all the input characters to our model
    x = torch.tensor([dataset.char_to_index[char] for char in chars])
    x = x.unsqueeze(0) # create a batch of 1
    x = x.to(device)

    for i in range(0, next_chars):
        
        y_pred, state = model(x, state)

        last_char_logits = y_pred[0][-1]
        p = torch.nn.functional.softmax(last_char_logits, dim=0).detach().cpu().numpy()
        char_index = np.random.choice(len(last_char_logits), p=p)
        chars.append(dataset.index_to_char[char_index])

        # the output of the model (a single character index) becomes the input at next iteration
        x = torch.tensor([[char_index]])
        x = x.to(device)

    return chars

predicted = predict(ShakespeareDataset, model_gru,'ROMEO:')
print(''.join(predicted))
# Out:
# ROMEO:
# O, this unlook'd-foot of a furricharity,
# Go to Pomfret, I am sound.
#
# LUCIO:
# And I am with you of his passing burden weeps.
# Go forswear your curse; say 'tis not quick by the
# gross: if these same that you speak combated,
# Have rich to foul injury, funching crown,
# And that the red present out first seeing,
# Hath parts the ribble of the west to live
# Till answer usurping him.
#
# SICINIUS:
# Nines were behind this facin the bastard.
#
# MENENIUS:
# Let me have't; I know the crown may never die.
#
# KING HENRY VI:
# Edward was Lucentio stand on the new.
#
# LADY GREY:
# To do that ever will be done.
# The people devouring the proud kingly senate.
#
# HENRY BOLINGBROKE:
# 'Tis true: ha, brought thyself and Edward's
# sharp spirit, to help him here at hand, though then from mine eyes:
# Mether, I pray you, I am too much time to scarreth thee,
# And know your majesty thou didst sweet thence,
# But one by Clarence, father fight deposed.
#
# JULIET:
# How does your father, by yon soldiers?
#
# FLORIZEL:
# She speaks,
# I wish't both you that w

# %% [markdown]
# While some of the sentences are grammatically correct, most do not make sense. The model has not learned the meaning of words (we would need a much larger corpus for that, and probably a word level language model), but consider the following:
#
# * The model is character-based. When training started, the model did not know how to spell an English word, or that words were even a unit of text. Now it does a pretty decent job on spelling.
#
# * The structure of the output resembles a play, blocks of text generally begin with a speaker name, in all capital letters similar to the dataset.
#
# * The model is trained on small batches of text (100 characters each), and is still able to generate a longer sequence of text with coherent structure.

# %% [markdown]
# # Homework
#
# <span style="color:blue">
#
# **Exercise 3:** Build two new models: one using Simple RNN cells (torch.nn.RNN) instead of GRUs(torch.nn.RNN), and the other using LSTMs (torch.nn.LSTM). Train all three models (GRU, LSTM, SimpleRNN) for 30 epochs and compare the loss curves. You can optionally try different configurations: embedding dimension, hidden layers dimensions, number of layers, etc.
#
# </span>

# %%
# YOUR RESPONSE HERE
class Model_RNN(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.2):
        super(Model_RNN, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers
        
        # YOUR CODE HERE
        self.embedding = nn.Embedding(input_dim, embedding_dim) 
        self.rnn = nn.RNN(input_size = embedding_dim, hidden_size = hidden_dim, num_layers = n_layers, dropout=drop_prob, batch_first=True)
        self.fc = nn.Linear(in_features = hidden_dim, out_features = output_dim)
        
        
    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.rnn(emb, h)
        out = self.fc(out)
        return out, h
    
    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        hidden = torch.zeros(self.n_layers, batch_size, self.hidden_dim, device=device)
        return hidden

# %%
# YOUR RESPONSE HERE
class Model_LSTM(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.2):
        super(Model_LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers
        
        # YOUR CODE HERE
        self.embedding = nn.Embedding(input_dim, embedding_dim) 
        self.lstm = nn.LSTM(input_size = embedding_dim, hidden_size = hidden_dim, num_layers = n_layers, dropout=drop_prob, batch_first=True)
        self.fc = nn.Linear(in_features = hidden_dim, out_features = output_dim)
        
        
    def forward(self, x, h):
        emb = self.embedding(x)
        out, (h,c) = self.lstm(emb, h)
        out = self.fc(out)
        return out, (h,c)
    
    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        hidden = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        cell = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return hidden, cell

# %%
def train_LSTM(dataloader, model, batch_size, sequence_length, num_epochs):
    model.train()

    criterion =  nn.CrossEntropyLoss() #CODE HERE
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    losses = []
    for epoch in range(num_epochs):

        for batch, (x, y) in enumerate(dataloader): # Start with a new state in each batch            
            hidden, cell = model.init_hidden(batch_size) # Start with a new state in each batch
            hidden = hidden.to(device)
            cell = cell.to(device)
            
            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            
            y_pred, (hidden, cell) = model(x, (hidden, cell))
            loss = criterion(y_pred.transpose(1, 2), y)

            loss.backward()
            optimizer.step()

            if batch%30 == 0:
                print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
                losses.append(loss.item())
    return losses

# %%
input_dim = len(ShakespeareDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(ShakespeareDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

model_rnn = Model_RNN(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)
model_lstm = Model_LSTM(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(model_rnn)
print(model_lstm)
# Out:
# Model_RNN(
#   (embedding): Embedding(65, 300)
#   (rnn): RNN(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )
# Model_LSTM(
#   (embedding): Embedding(65, 300)
#   (lstm): LSTM(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )

# %%
num_epochs = 30
print('TRAINING MODEL: ', model_gru, '\n')
losses = train(train_loader, model_gru, batch_size, sequence_length, num_epochs)
# Out:
# TRAINING MODEL:  Model(
#   (embedding): Embedding(65, 300)
#   (gru): GRU(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )
#
# {'epoch': 0, 'batch': 0, 'loss': 0.8444502353668213}
# {'epoch': 0, 'batch': 30, 'loss': 0.8712753057479858}
# {'epoch': 0, 'batch': 60, 'loss': 0.8646984696388245}
# {'epoch': 0, 'batch': 90, 'loss': 0.8520839214324951}
# {'epoch': 0, 'batch': 120, 'loss': 0.8501459360122681}
# {'epoch': 0, 'batch': 150, 'loss': 0.8782378435134888}
# {'epoch': 1, 'batch': 0, 'loss': 0.8091503977775574}
# {'epoch': 1, 'batch': 30, 'loss': 0.7899231910705566}
# {'epoch': 1, 'batch': 60, 'loss': 0.8099606037139893}
# {'epoch': 1, 'batch': 90, 'loss': 0.838082492351532}
# {'epoch': 1, 'batch': 120, 'loss': 0.8420107960700989}
# {'epoch': 1, 'batch': 150, 'loss': 0.8438819646835327}
# {'epoch': 2, 'batch': 0, 'loss': 0.7590304613113403}
# {'epoch': 2, 'batch': 30, 'loss': 0.7587871551513672}
# {'epoch': 2, 'batch': 60, 'loss': 0.7967978119850159}
# {'epoch': 2, 'batch': 90, 'loss': 0.7936046123504639}
# {'epoch': 2, 'batch': 120, 'loss': 0.8629341721534729}
# {'epoch': 2, 'batch': 150, 'loss': 0.866629958152771}
# {'epoch': 3, 'batch': 0, 'loss': 0.7686641812324524}
# {'epoch': 3, 'batch': 30, 'loss': 0.7810763716697693}
# {'epoch': 3, 'batch': 60, 'loss': 0.7862976789474487}
# {'epoch': 3, 'batch': 90, 'loss': 0.8136543035507202}
# {'epoch': 3, 'batch': 120, 'loss': 0.8224567174911499}
# {'epoch': 3, 'batch': 150, 'loss': 0.8433377742767334}
# {'epoch': 4, 'batch': 0, 'loss': 0.7335245609283447}
# {'epoch': 4, 'batch': 30, 'loss': 0.7666544318199158}
# {'epoch': 4, 'batch': 60, 'loss': 0.7773565053939819}
# {'epoch': 4, 'batch': 90, 'loss': 0.7997627258300781}
# {'epoch': 4, 'batch': 120, 'loss': 0.8288759589195251}
# {'epoch': 4, 'batch': 150, 'loss': 0.8471542596817017}
# {'epoch': 5, 'batch': 0, 'loss': 0.7575933933258057}
# {'epoch': 5, 'batch': 30, 'loss': 0.7620370984077454}
# {'epoch': 5, 'batch': 60, 'loss': 0.7812252044677734}
# {'epoch': 5, 'batch': 90, 'loss': 0.840058445930481}
# {'epoch': 5, 'batch': 120, 'loss': 0.8117591142654419}
# {'epoch': 5, 'batch': 150, 'loss': 0.832908034324646}
# {'epoch': 6, 'batch': 0, 'loss': 0.7494091987609863}
# {'epoch': 6, 'batch': 30, 'loss': 0.7753796577453613}
# {'epoch': 6, 'batch': 60, 'loss': 0.7841224670410156}
# {'epoch': 6, 'batch': 90, 'loss': 0.8242553472518921}
# {'epoch': 6, 'batch': 120, 'loss': 0.820712149143219}
# {'epoch': 6, 'batch': 150, 'loss': 0.8347322344779968}
# {'epoch': 7, 'batch': 0, 'loss': 0.7656162977218628}
# {'epoch': 7, 'batch': 30, 'loss': 0.7705890536308289}
# {'epoch': 7, 'batch': 60, 'loss': 0.7790641188621521}
# {'epoch': 7, 'batch': 90, 'loss': 0.824492335319519}
# {'epoch': 7, 'batch': 120, 'loss': 0.8087714314460754}
# {'epoch': 7, 'batch': 150, 'loss': 0.8079667091369629}
# {'epoch': 8, 'batch': 0, 'loss': 0.7863925695419312}
# {'epoch': 8, 'batch': 30, 'loss': 0.7580268383026123}
# {'epoch': 8, 'batch': 60, 'loss': 0.7950462102890015}
# {'epoch': 8, 'batch': 90, 'loss': 0.8231141567230225}
# {'epoch': 8, 'batch': 120, 'loss': 0.8423144817352295}
# {'epoch': 8, 'batch': 150, 'loss': 0.8343412280082703}
# {'epoch': 9, 'batch': 0, 'loss': 0.7560065388679504}
# {'epoch': 9, 'batch': 30, 'loss': 0.7918727993965149}
# {'epoch': 9, 'batch': 60, 'loss': 0.8081852793693542}
# {'epoch': 9, 'batch': 90, 'loss': 0.7976482510566711}
# {'epoch': 9, 'batch': 120, 'loss': 0.817249059677124}
# {'epoch': 9, 'batch': 150, 'loss': 0.8554107546806335}
# {'epoch': 10, 'batch': 0, 'loss': 0.7741491794586182}
# {'epoch': 10, 'batch': 30, 'loss': 0.7851872444152832}
# {'epoch': 10, 'batch': 60, 'loss': 0.7868638634681702}
# {'epoch': 10, 'batch': 90, 'loss': 0.8105722069740295}
# {'epoch': 10, 'batch': 120, 'loss': 0.8394896984100342}
# {'epoch': 10, 'batch': 150, 'loss': 0.856814444065094}
# {'epoch': 11, 'batch': 0, 'loss': 0.7776098847389221}
# {'epoch': 11, 'batch': 30, 'loss': 0.775627613067627}
# {'epoch': 11, 'batch': 60, 'loss': 0.8013768792152405}
# {'epoch': 11, 'batch': 90, 'loss': 0.825346827507019}
# {'epoch': 11, 'batch': 120, 'loss': 0.8574646711349487}
# {'epoch': 11, 'batch': 150, 'loss': 0.8615953922271729}
# {'epoch': 12, 'batch': 0, 'loss': 0.7811164855957031}
# {'epoch': 12, 'batch': 30, 'loss': 0.799834668636322}
# {'epoch': 12, 'batch': 60, 'loss': 0.821931779384613}
# {'epoch': 12, 'batch': 90, 'loss': 0.8313704133033752}
# {'epoch': 12, 'batch': 120, 'loss': 0.8796811699867249}
# {'epoch': 12, 'batch': 150, 'loss': 0.8695597648620605}
# {'epoch': 13, 'batch': 0, 'loss': 0.7843140363693237}
# {'epoch': 13, 'batch': 30, 'loss': 0.8167136907577515}
# {'epoch': 13, 'batch': 60, 'loss': 0.8335909843444824}
# {'epoch': 13, 'batch': 90, 'loss': 0.8298904299736023}
# {'epoch': 13, 'batch': 120, 'loss': 0.8557146191596985}
# {'epoch': 13, 'batch': 150, 'loss': 0.8815757632255554}
# {'epoch': 14, 'batch': 0, 'loss': 0.7985278964042664}
# {'epoch': 14, 'batch': 30, 'loss': 0.8143873810768127}
# {'epoch': 14, 'batch': 60, 'loss': 0.817160427570343}
# {'epoch': 14, 'batch': 90, 'loss': 0.8523279428482056}
# {'epoch': 14, 'batch': 120, 'loss': 0.8822177052497864}
# {'epoch': 14, 'batch': 150, 'loss': 0.8834162354469299}
# {'epoch': 15, 'batch': 0, 'loss': 0.8100306987762451}
# {'epoch': 15, 'batch': 30, 'loss': 0.8126890063285828}
# {'epoch': 15, 'batch': 60, 'loss': 0.8485382199287415}
# {'epoch': 15, 'batch': 90, 'loss': 0.8667809367179871}
# {'epoch': 15, 'batch': 120, 'loss': 0.868621289730072}
# {'epoch': 15, 'batch': 150, 'loss': 0.9017745852470398}
# {'epoch': 16, 'batch': 0, 'loss': 0.8451545834541321}
# {'epoch': 16, 'batch': 30, 'loss': 0.8337001800537109}
# {'epoch': 16, 'batch': 60, 'loss': 0.826122522354126}
# {'epoch': 16, 'batch': 90, 'loss': 0.8479524850845337}
# {'epoch': 16, 'batch': 120, 'loss': 0.8786827921867371}
# {'epoch': 16, 'batch': 150, 'loss': 0.8893236517906189}
# {'epoch': 17, 'batch': 0, 'loss': 0.8306683301925659}
# {'epoch': 17, 'batch': 30, 'loss': 0.8302836418151855}
# {'epoch': 17, 'batch': 60, 'loss': 0.8868163824081421}
# {'epoch': 17, 'batch': 90, 'loss': 0.8825544118881226}
# {'epoch': 17, 'batch': 120, 'loss': 0.9083172678947449}
# {'epoch': 17, 'batch': 150, 'loss': 0.9080682992935181}
# {'epoch': 18, 'batch': 0, 'loss': 0.8214721083641052}
# {'epoch': 18, 'batch': 30, 'loss': 0.8424983024597168}
# {'epoch': 18, 'batch': 60, 'loss': 0.8786274194717407}
# {'epoch': 18, 'batch': 90, 'loss': 0.9190491437911987}
# {'epoch': 18, 'batch': 120, 'loss': 0.900790810585022}
# {'epoch': 18, 'batch': 150, 'loss': 0.9042196869850159}
# {'epoch': 19, 'batch': 0, 'loss': 0.8258303999900818}
# {'epoch': 19, 'batch': 30, 'loss': 0.8529015183448792}
# {'epoch': 19, 'batch': 60, 'loss': 0.8711124658584595}
# {'epoch': 19, 'batch': 90, 'loss': 0.9046404957771301}
# {'epoch': 19, 'batch': 120, 'loss': 0.9258332848548889}
# {'epoch': 19, 'batch': 150, 'loss': 0.9318354725837708}
# {'epoch': 20, 'batch': 0, 'loss': 0.8678392171859741}
# {'epoch': 20, 'batch': 30, 'loss': 0.8750037550926208}
# {'epoch': 20, 'batch': 60, 'loss': 0.8987616896629333}
# {'epoch': 20, 'batch': 90, 'loss': 0.9081341028213501}
# {'epoch': 20, 'batch': 120, 'loss': 0.9095200300216675}
# {'epoch': 20, 'batch': 150, 'loss': 0.9378588795661926}
# {'epoch': 21, 'batch': 0, 'loss': 0.8646233081817627}
# {'epoch': 21, 'batch': 30, 'loss': 0.907387912273407}
# {'epoch': 21, 'batch': 60, 'loss': 0.9112715721130371}
# {'epoch': 21, 'batch': 90, 'loss': 0.9132262468338013}
# {'epoch': 21, 'batch': 120, 'loss': 0.9483451843261719}
# {'epoch': 21, 'batch': 150, 'loss': 0.9313555955886841}
# {'epoch': 22, 'batch': 0, 'loss': 0.906924307346344}
# {'epoch': 22, 'batch': 30, 'loss': 0.8867191076278687}
# {'epoch': 22, 'batch': 60, 'loss': 0.9300457835197449}
# {'epoch': 22, 'batch': 90, 'loss': 0.9301650524139404}
# {'epoch': 22, 'batch': 120, 'loss': 0.9453270435333252}
# {'epoch': 22, 'batch': 150, 'loss': 0.9709129929542542}
# {'epoch': 23, 'batch': 0, 'loss': 0.880689799785614}
# {'epoch': 23, 'batch': 30, 'loss': 0.9283052086830139}
# {'epoch': 23, 'batch': 60, 'loss': 0.919718325138092}
# {'epoch': 23, 'batch': 90, 'loss': 0.948691725730896}
# {'epoch': 23, 'batch': 120, 'loss': 0.9650668501853943}
# {'epoch': 23, 'batch': 150, 'loss': 0.9385395050048828}
# {'epoch': 24, 'batch': 0, 'loss': 0.9113000631332397}
# {'epoch': 24, 'batch': 30, 'loss': 0.9389466047286987}
# {'epoch': 24, 'batch': 60, 'loss': 0.933514416217804}
# {'epoch': 24, 'batch': 90, 'loss': 0.9786534309387207}
# {'epoch': 24, 'batch': 120, 'loss': 0.9623640179634094}
# {'epoch': 24, 'batch': 150, 'loss': 0.9939436912536621}
# {'epoch': 25, 'batch': 0, 'loss': 0.9391366839408875}
# {'epoch': 25, 'batch': 30, 'loss': 0.9198156595230103}
# {'epoch': 25, 'batch': 60, 'loss': 0.9660821557044983}
# {'epoch': 25, 'batch': 90, 'loss': 0.9843927621841431}
# {'epoch': 25, 'batch': 120, 'loss': 0.9639500975608826}
# {'epoch': 25, 'batch': 150, 'loss': 1.013316035270691}
# {'epoch': 26, 'batch': 0, 'loss': 0.9357085227966309}
# {'epoch': 26, 'batch': 30, 'loss': 0.9580308794975281}
# {'epoch': 26, 'batch': 60, 'loss': 0.9800052046775818}
# {'epoch': 26, 'batch': 90, 'loss': 1.0018500089645386}
# {'epoch': 26, 'batch': 120, 'loss': 0.9742369055747986}
# {'epoch': 26, 'batch': 150, 'loss': 0.9821211099624634}
# {'epoch': 27, 'batch': 0, 'loss': 0.9861415028572083}
# {'epoch': 27, 'batch': 30, 'loss': 0.9688851237297058}
# {'epoch': 27, 'batch': 60, 'loss': 0.9794385433197021}
# {'epoch': 27, 'batch': 90, 'loss': 1.0218801498413086}
# {'epoch': 27, 'batch': 120, 'loss': 1.0231753587722778}
# {'epoch': 27, 'batch': 150, 'loss': 1.038891077041626}
# {'epoch': 28, 'batch': 0, 'loss': 0.9524480700492859}
# {'epoch': 28, 'batch': 30, 'loss': 0.9921476244926453}
# {'epoch': 28, 'batch': 60, 'loss': 1.0133452415466309}
# {'epoch': 28, 'batch': 90, 'loss': 1.0300710201263428}
# {'epoch': 28, 'batch': 120, 'loss': 1.0394431352615356}
# {'epoch': 28, 'batch': 150, 'loss': 1.0568287372589111}
# {'epoch': 29, 'batch': 0, 'loss': 1.0129740238189697}
# {'epoch': 29, 'batch': 30, 'loss': 0.9810473918914795}
# {'epoch': 29, 'batch': 60, 'loss': 1.0516130924224854}
# {'epoch': 29, 'batch': 90, 'loss': 1.0037503242492676}
# {'epoch': 29, 'batch': 120, 'loss': 1.0524804592132568}
# {'epoch': 29, 'batch': 150, 'loss': 1.0510257482528687}

# %%
# Visualize the loss evolution during training
plt.plot(losses)
plt.title('model loss')
plt.show()

# %%
num_epochs = 30
losses = train(train_loader, model_rnn, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.183346271514893}
# {'epoch': 0, 'batch': 30, 'loss': 2.2589309215545654}
# {'epoch': 0, 'batch': 60, 'loss': 1.9895902872085571}
# {'epoch': 0, 'batch': 90, 'loss': 1.9100871086120605}
# {'epoch': 0, 'batch': 120, 'loss': 1.8596560955047607}
# {'epoch': 0, 'batch': 150, 'loss': 1.7838525772094727}
# {'epoch': 1, 'batch': 0, 'loss': 1.7253271341323853}
# {'epoch': 1, 'batch': 30, 'loss': 1.6391074657440186}
# {'epoch': 1, 'batch': 60, 'loss': 1.6106681823730469}
# {'epoch': 1, 'batch': 90, 'loss': 1.603949785232544}
# {'epoch': 1, 'batch': 120, 'loss': 1.5577151775360107}
# {'epoch': 1, 'batch': 150, 'loss': 1.53118097782135}
# {'epoch': 2, 'batch': 0, 'loss': 1.502334475517273}
# {'epoch': 2, 'batch': 30, 'loss': 1.5492233037948608}
# {'epoch': 2, 'batch': 60, 'loss': 1.491241455078125}
# {'epoch': 2, 'batch': 90, 'loss': 1.5227546691894531}
# {'epoch': 2, 'batch': 120, 'loss': 1.4792824983596802}
# {'epoch': 2, 'batch': 150, 'loss': 1.4550164937973022}
# {'epoch': 3, 'batch': 0, 'loss': 1.4416559934616089}
# {'epoch': 3, 'batch': 30, 'loss': 1.4197086095809937}
# {'epoch': 3, 'batch': 60, 'loss': 1.4281997680664062}
# {'epoch': 3, 'batch': 90, 'loss': 1.4900238513946533}
# {'epoch': 3, 'batch': 120, 'loss': 1.4798650741577148}
# {'epoch': 3, 'batch': 150, 'loss': 1.4412107467651367}
# {'epoch': 4, 'batch': 0, 'loss': 1.4287512302398682}
# {'epoch': 4, 'batch': 30, 'loss': 1.3850467205047607}
# {'epoch': 4, 'batch': 60, 'loss': 1.433078646659851}
# {'epoch': 4, 'batch': 90, 'loss': 1.3903437852859497}
# {'epoch': 4, 'batch': 120, 'loss': 1.3577247858047485}
# {'epoch': 4, 'batch': 150, 'loss': 1.3777042627334595}
# {'epoch': 5, 'batch': 0, 'loss': 1.3617167472839355}
# {'epoch': 5, 'batch': 30, 'loss': 1.375450611114502}
# {'epoch': 5, 'batch': 60, 'loss': 1.3495917320251465}
# {'epoch': 5, 'batch': 90, 'loss': 1.3567379713058472}
# {'epoch': 5, 'batch': 120, 'loss': 1.371951937675476}
# {'epoch': 5, 'batch': 150, 'loss': 1.3604289293289185}
# {'epoch': 6, 'batch': 0, 'loss': 1.29561185836792}
# {'epoch': 6, 'batch': 30, 'loss': 1.3056671619415283}
# {'epoch': 6, 'batch': 60, 'loss': 1.3166756629943848}
# {'epoch': 6, 'batch': 90, 'loss': 1.3699400424957275}
# {'epoch': 6, 'batch': 120, 'loss': 1.2969067096710205}
# {'epoch': 6, 'batch': 150, 'loss': 1.3387678861618042}
# {'epoch': 7, 'batch': 0, 'loss': 1.296741008758545}
# {'epoch': 7, 'batch': 30, 'loss': 1.3077759742736816}
# {'epoch': 7, 'batch': 60, 'loss': 1.3089704513549805}
# {'epoch': 7, 'batch': 90, 'loss': 1.3096356391906738}
# {'epoch': 7, 'batch': 120, 'loss': 1.3206387758255005}
# {'epoch': 7, 'batch': 150, 'loss': 1.2985119819641113}
# {'epoch': 8, 'batch': 0, 'loss': 1.3231219053268433}
# {'epoch': 8, 'batch': 30, 'loss': 1.247240662574768}
# {'epoch': 8, 'batch': 60, 'loss': 1.301089882850647}
# {'epoch': 8, 'batch': 90, 'loss': 1.3074631690979004}
# {'epoch': 8, 'batch': 120, 'loss': 1.294287919998169}
# {'epoch': 8, 'batch': 150, 'loss': 1.2628679275512695}
# {'epoch': 9, 'batch': 0, 'loss': 1.2590913772583008}
# {'epoch': 9, 'batch': 30, 'loss': 1.2669329643249512}
# {'epoch': 9, 'batch': 60, 'loss': 1.2777800559997559}
# {'epoch': 9, 'batch': 90, 'loss': 1.2806036472320557}
# {'epoch': 9, 'batch': 120, 'loss': 1.2862038612365723}
# {'epoch': 9, 'batch': 150, 'loss': 1.2895489931106567}
# {'epoch': 10, 'batch': 0, 'loss': 1.2713111639022827}
# {'epoch': 10, 'batch': 30, 'loss': 1.2450015544891357}
# {'epoch': 10, 'batch': 60, 'loss': 1.264157772064209}
# {'epoch': 10, 'batch': 90, 'loss': 1.2270805835723877}
# {'epoch': 10, 'batch': 120, 'loss': 1.3028455972671509}
# {'epoch': 10, 'batch': 150, 'loss': 1.2950057983398438}
# {'epoch': 11, 'batch': 0, 'loss': 1.2247636318206787}
# {'epoch': 11, 'batch': 30, 'loss': 1.272350788116455}
# {'epoch': 11, 'batch': 60, 'loss': 1.2165720462799072}
# {'epoch': 11, 'batch': 90, 'loss': 1.245403528213501}
# {'epoch': 11, 'batch': 120, 'loss': 1.2558609247207642}
# {'epoch': 11, 'batch': 150, 'loss': 1.2926499843597412}
# {'epoch': 12, 'batch': 0, 'loss': 1.236756682395935}
# {'epoch': 12, 'batch': 30, 'loss': 1.252314567565918}
# {'epoch': 12, 'batch': 60, 'loss': 1.2090014219284058}
# {'epoch': 12, 'batch': 90, 'loss': 1.2186723947525024}
# {'epoch': 12, 'batch': 120, 'loss': 1.2464165687561035}
# {'epoch': 12, 'batch': 150, 'loss': 1.2265602350234985}
# {'epoch': 13, 'batch': 0, 'loss': 1.2220637798309326}
# {'epoch': 13, 'batch': 30, 'loss': 1.2209131717681885}
# {'epoch': 13, 'batch': 60, 'loss': 1.2117706537246704}
# {'epoch': 13, 'batch': 90, 'loss': 1.2607330083847046}
# {'epoch': 13, 'batch': 120, 'loss': 1.2520982027053833}
# {'epoch': 13, 'batch': 150, 'loss': 1.2422609329223633}
# {'epoch': 14, 'batch': 0, 'loss': 1.2162809371948242}
# {'epoch': 14, 'batch': 30, 'loss': 1.194861650466919}
# {'epoch': 14, 'batch': 60, 'loss': 1.193150281906128}
# {'epoch': 14, 'batch': 90, 'loss': 1.229640245437622}
# {'epoch': 14, 'batch': 120, 'loss': 1.2641278505325317}
# {'epoch': 14, 'batch': 150, 'loss': 1.224027395248413}
# {'epoch': 15, 'batch': 0, 'loss': 1.1934881210327148}
# {'epoch': 15, 'batch': 30, 'loss': 1.1929627656936646}
# {'epoch': 15, 'batch': 60, 'loss': 1.2019320726394653}
# {'epoch': 15, 'batch': 90, 'loss': 1.1747181415557861}
# {'epoch': 15, 'batch': 120, 'loss': 1.2075750827789307}
# {'epoch': 15, 'batch': 150, 'loss': 1.2411216497421265}
# {'epoch': 16, 'batch': 0, 'loss': 1.1878597736358643}
# {'epoch': 16, 'batch': 30, 'loss': 1.1704291105270386}
# {'epoch': 16, 'batch': 60, 'loss': 1.1965442895889282}
# {'epoch': 16, 'batch': 90, 'loss': 1.2272374629974365}
# {'epoch': 16, 'batch': 120, 'loss': 1.216620683670044}
# {'epoch': 16, 'batch': 150, 'loss': 1.1985571384429932}
# {'epoch': 17, 'batch': 0, 'loss': 1.150641679763794}
# {'epoch': 17, 'batch': 30, 'loss': 1.2044041156768799}
# {'epoch': 17, 'batch': 60, 'loss': 1.216607689857483}
# {'epoch': 17, 'batch': 90, 'loss': 1.2086684703826904}
# {'epoch': 17, 'batch': 120, 'loss': 1.2055811882019043}
# {'epoch': 17, 'batch': 150, 'loss': 1.1986385583877563}
# {'epoch': 18, 'batch': 0, 'loss': 1.165988802909851}
# {'epoch': 18, 'batch': 30, 'loss': 1.186458945274353}
# {'epoch': 18, 'batch': 60, 'loss': 1.186811923980713}
# {'epoch': 18, 'batch': 90, 'loss': 1.1748477220535278}
# {'epoch': 18, 'batch': 120, 'loss': 1.1695691347122192}
# {'epoch': 18, 'batch': 150, 'loss': 1.2235838174819946}
# {'epoch': 19, 'batch': 0, 'loss': 1.1799342632293701}
# {'epoch': 19, 'batch': 30, 'loss': 1.1721078157424927}
# {'epoch': 19, 'batch': 60, 'loss': 1.1560133695602417}
# {'epoch': 19, 'batch': 90, 'loss': 1.198007583618164}
# {'epoch': 19, 'batch': 120, 'loss': 1.198768138885498}
# {'epoch': 19, 'batch': 150, 'loss': 1.2039027214050293}
# {'epoch': 20, 'batch': 0, 'loss': 1.1315993070602417}
# {'epoch': 20, 'batch': 30, 'loss': 1.1715233325958252}
# {'epoch': 20, 'batch': 60, 'loss': 1.1806923151016235}
# {'epoch': 20, 'batch': 90, 'loss': 1.1805195808410645}
# {'epoch': 20, 'batch': 120, 'loss': 1.2424179315567017}
# {'epoch': 20, 'batch': 150, 'loss': 1.1712270975112915}
# {'epoch': 21, 'batch': 0, 'loss': 1.1508991718292236}
# {'epoch': 21, 'batch': 30, 'loss': 1.153813123703003}
# {'epoch': 21, 'batch': 60, 'loss': 1.1752468347549438}
# {'epoch': 21, 'batch': 90, 'loss': 1.158394694328308}
# {'epoch': 21, 'batch': 120, 'loss': 1.169830322265625}
# {'epoch': 21, 'batch': 150, 'loss': 1.1796092987060547}
# {'epoch': 22, 'batch': 0, 'loss': 1.1389423608779907}
# {'epoch': 22, 'batch': 30, 'loss': 1.148429274559021}
# {'epoch': 22, 'batch': 60, 'loss': 1.1736177206039429}
# {'epoch': 22, 'batch': 90, 'loss': 1.1696093082427979}
# {'epoch': 22, 'batch': 120, 'loss': 1.1583960056304932}
# {'epoch': 22, 'batch': 150, 'loss': 1.187964916229248}
# {'epoch': 23, 'batch': 0, 'loss': 1.133338451385498}
# {'epoch': 23, 'batch': 30, 'loss': 1.1437517404556274}
# {'epoch': 23, 'batch': 60, 'loss': 1.1749149560928345}
# {'epoch': 23, 'batch': 90, 'loss': 1.1814848184585571}
# {'epoch': 23, 'batch': 120, 'loss': 1.175582766532898}
# {'epoch': 23, 'batch': 150, 'loss': 1.195664882659912}
# {'epoch': 24, 'batch': 0, 'loss': 1.143447756767273}
# {'epoch': 24, 'batch': 30, 'loss': 1.1520384550094604}
# {'epoch': 24, 'batch': 60, 'loss': 1.1139471530914307}
# {'epoch': 24, 'batch': 90, 'loss': 1.1515141725540161}
# {'epoch': 24, 'batch': 120, 'loss': 1.15507972240448}
# {'epoch': 24, 'batch': 150, 'loss': 1.183673620223999}
# {'epoch': 25, 'batch': 0, 'loss': 1.124737024307251}
# {'epoch': 25, 'batch': 30, 'loss': 1.1326671838760376}
# {'epoch': 25, 'batch': 60, 'loss': 1.1371499300003052}
# {'epoch': 25, 'batch': 90, 'loss': 1.1618216037750244}
# {'epoch': 25, 'batch': 120, 'loss': 1.122091293334961}
# {'epoch': 25, 'batch': 150, 'loss': 1.198022484779358}
# {'epoch': 26, 'batch': 0, 'loss': 1.1560078859329224}
# {'epoch': 26, 'batch': 30, 'loss': 1.1505454778671265}
# {'epoch': 26, 'batch': 60, 'loss': 1.1250033378601074}
# {'epoch': 26, 'batch': 90, 'loss': 1.1619209051132202}
# {'epoch': 26, 'batch': 120, 'loss': 1.1562446355819702}
# {'epoch': 26, 'batch': 150, 'loss': 1.160083293914795}
# {'epoch': 27, 'batch': 0, 'loss': 1.132864236831665}
# {'epoch': 27, 'batch': 30, 'loss': 1.114375352859497}
# {'epoch': 27, 'batch': 60, 'loss': 1.160513162612915}
# {'epoch': 27, 'batch': 90, 'loss': 1.1515082120895386}
# {'epoch': 27, 'batch': 120, 'loss': 1.1386628150939941}
# {'epoch': 27, 'batch': 150, 'loss': 1.1372368335723877}
# {'epoch': 28, 'batch': 0, 'loss': 1.1155683994293213}
# {'epoch': 28, 'batch': 30, 'loss': 1.1325600147247314}
# {'epoch': 28, 'batch': 60, 'loss': 1.1564443111419678}
# {'epoch': 28, 'batch': 90, 'loss': 1.1808645725250244}
# {'epoch': 28, 'batch': 120, 'loss': 1.1842073202133179}
# {'epoch': 28, 'batch': 150, 'loss': 1.16158127784729}
# {'epoch': 29, 'batch': 0, 'loss': 1.1099570989608765}
# {'epoch': 29, 'batch': 30, 'loss': 1.1350401639938354}
# {'epoch': 29, 'batch': 60, 'loss': 1.1372706890106201}
# {'epoch': 29, 'batch': 90, 'loss': 1.1482279300689697}
# {'epoch': 29, 'batch': 120, 'loss': 1.148464560508728}
# {'epoch': 29, 'batch': 150, 'loss': 1.1408944129943848}

# %%
# Visualize the loss evolution during training
plt.plot(losses)
plt.title('model loss')
plt.show()

# %%
num_epochs = 30
print('TRAINING MODEL: ', model_lstm, '\n')
losses = train_LSTM(train_loader, model_lstm, batch_size, sequence_length, num_epochs)
# Out:
# TRAINING MODEL:  Model_LSTM(
#   (embedding): Embedding(65, 300)
#   (lstm): LSTM(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )
#
# {'epoch': 0, 'batch': 0, 'loss': 4.1670660972595215}
# {'epoch': 0, 'batch': 30, 'loss': 2.2681689262390137}
# {'epoch': 0, 'batch': 60, 'loss': 1.946418285369873}
# {'epoch': 0, 'batch': 90, 'loss': 1.7308610677719116}
# {'epoch': 0, 'batch': 120, 'loss': 1.648403286933899}
# {'epoch': 0, 'batch': 150, 'loss': 1.5827962160110474}
# {'epoch': 1, 'batch': 0, 'loss': 1.5605205297470093}
# {'epoch': 1, 'batch': 30, 'loss': 1.5169888734817505}
# {'epoch': 1, 'batch': 60, 'loss': 1.4599800109863281}
# {'epoch': 1, 'batch': 90, 'loss': 1.465334177017212}
# {'epoch': 1, 'batch': 120, 'loss': 1.4321538209915161}
# {'epoch': 1, 'batch': 150, 'loss': 1.4327470064163208}
# {'epoch': 2, 'batch': 0, 'loss': 1.3334541320800781}
# {'epoch': 2, 'batch': 30, 'loss': 1.3470726013183594}
# {'epoch': 2, 'batch': 60, 'loss': 1.341091513633728}
# {'epoch': 2, 'batch': 90, 'loss': 1.3506252765655518}
# {'epoch': 2, 'batch': 120, 'loss': 1.347200632095337}
# {'epoch': 2, 'batch': 150, 'loss': 1.3243528604507446}
# {'epoch': 3, 'batch': 0, 'loss': 1.2895195484161377}
# {'epoch': 3, 'batch': 30, 'loss': 1.3089795112609863}
# {'epoch': 3, 'batch': 60, 'loss': 1.2596980333328247}
# {'epoch': 3, 'batch': 90, 'loss': 1.318845272064209}
# {'epoch': 3, 'batch': 120, 'loss': 1.2985754013061523}
# {'epoch': 3, 'batch': 150, 'loss': 1.2705692052841187}
# {'epoch': 4, 'batch': 0, 'loss': 1.244584321975708}
# {'epoch': 4, 'batch': 30, 'loss': 1.2543220520019531}
# {'epoch': 4, 'batch': 60, 'loss': 1.243393898010254}
# {'epoch': 4, 'batch': 90, 'loss': 1.2503938674926758}
# {'epoch': 4, 'batch': 120, 'loss': 1.2321410179138184}
# {'epoch': 4, 'batch': 150, 'loss': 1.2471293210983276}
# {'epoch': 5, 'batch': 0, 'loss': 1.1772339344024658}
# {'epoch': 5, 'batch': 30, 'loss': 1.1686252355575562}
# {'epoch': 5, 'batch': 60, 'loss': 1.1624082326889038}
# {'epoch': 5, 'batch': 90, 'loss': 1.18747079372406}
# {'epoch': 5, 'batch': 120, 'loss': 1.1916905641555786}
# {'epoch': 5, 'batch': 150, 'loss': 1.2266888618469238}
# {'epoch': 6, 'batch': 0, 'loss': 1.1456259489059448}
# {'epoch': 6, 'batch': 30, 'loss': 1.142646074295044}
# {'epoch': 6, 'batch': 60, 'loss': 1.1321274042129517}
# {'epoch': 6, 'batch': 90, 'loss': 1.143700361251831}
# {'epoch': 6, 'batch': 120, 'loss': 1.1542989015579224}
# {'epoch': 6, 'batch': 150, 'loss': 1.1760354042053223}
# {'epoch': 7, 'batch': 0, 'loss': 1.0874935388565063}
# {'epoch': 7, 'batch': 30, 'loss': 1.1006149053573608}
# {'epoch': 7, 'batch': 60, 'loss': 1.108921766281128}
# {'epoch': 7, 'batch': 90, 'loss': 1.1409962177276611}
# {'epoch': 7, 'batch': 120, 'loss': 1.1318693161010742}
# {'epoch': 7, 'batch': 150, 'loss': 1.1135249137878418}
# {'epoch': 8, 'batch': 0, 'loss': 1.0511565208435059}
# {'epoch': 8, 'batch': 30, 'loss': 1.0318799018859863}
# {'epoch': 8, 'batch': 60, 'loss': 1.0794249773025513}
# {'epoch': 8, 'batch': 90, 'loss': 1.0708236694335938}
# {'epoch': 8, 'batch': 120, 'loss': 1.0976920127868652}
# {'epoch': 8, 'batch': 150, 'loss': 1.0788769721984863}
# {'epoch': 9, 'batch': 0, 'loss': 1.0045870542526245}
# {'epoch': 9, 'batch': 30, 'loss': 0.982677161693573}
# {'epoch': 9, 'batch': 60, 'loss': 1.0207462310791016}
# {'epoch': 9, 'batch': 90, 'loss': 1.0518685579299927}
# {'epoch': 9, 'batch': 120, 'loss': 1.0489810705184937}
# {'epoch': 9, 'batch': 150, 'loss': 1.0696425437927246}
# {'epoch': 10, 'batch': 0, 'loss': 0.9320354461669922}
# {'epoch': 10, 'batch': 30, 'loss': 0.9622648358345032}
# {'epoch': 10, 'batch': 60, 'loss': 0.9769315123558044}
# {'epoch': 10, 'batch': 90, 'loss': 0.9845704436302185}
# {'epoch': 10, 'batch': 120, 'loss': 0.9948537349700928}
# {'epoch': 10, 'batch': 150, 'loss': 1.021108627319336}
# {'epoch': 11, 'batch': 0, 'loss': 0.9124079346656799}
# {'epoch': 11, 'batch': 30, 'loss': 0.8862892985343933}
# {'epoch': 11, 'batch': 60, 'loss': 0.9118988513946533}
# {'epoch': 11, 'batch': 90, 'loss': 0.9460121989250183}
# {'epoch': 11, 'batch': 120, 'loss': 0.961313784122467}
# {'epoch': 11, 'batch': 150, 'loss': 0.9822823405265808}
# {'epoch': 12, 'batch': 0, 'loss': 0.89034104347229}
# {'epoch': 12, 'batch': 30, 'loss': 0.8604463338851929}
# {'epoch': 12, 'batch': 60, 'loss': 0.8629212379455566}
# {'epoch': 12, 'batch': 90, 'loss': 0.9062573313713074}
# {'epoch': 12, 'batch': 120, 'loss': 0.8940253257751465}
# {'epoch': 12, 'batch': 150, 'loss': 0.9278116822242737}
# {'epoch': 13, 'batch': 0, 'loss': 0.8114793300628662}
# {'epoch': 13, 'batch': 30, 'loss': 0.8030834197998047}
# {'epoch': 13, 'batch': 60, 'loss': 0.8394544124603271}
# {'epoch': 13, 'batch': 90, 'loss': 0.8624539375305176}
# {'epoch': 13, 'batch': 120, 'loss': 0.8784629106521606}
# {'epoch': 13, 'batch': 150, 'loss': 0.8537526726722717}
# {'epoch': 14, 'batch': 0, 'loss': 0.7769734859466553}
# {'epoch': 14, 'batch': 30, 'loss': 0.7709361910820007}
# {'epoch': 14, 'batch': 60, 'loss': 0.780225396156311}
# {'epoch': 14, 'batch': 90, 'loss': 0.8184362053871155}
# {'epoch': 14, 'batch': 120, 'loss': 0.8213407397270203}
# {'epoch': 14, 'batch': 150, 'loss': 0.8576557040214539}
# {'epoch': 15, 'batch': 0, 'loss': 0.7179979085922241}
# {'epoch': 15, 'batch': 30, 'loss': 0.730522632598877}
# {'epoch': 15, 'batch': 60, 'loss': 0.7757916450500488}
# {'epoch': 15, 'batch': 90, 'loss': 0.7679628729820251}
# {'epoch': 15, 'batch': 120, 'loss': 0.7967562675476074}
# {'epoch': 15, 'batch': 150, 'loss': 0.8098081350326538}
# {'epoch': 16, 'batch': 0, 'loss': 0.6903721690177917}
# {'epoch': 16, 'batch': 30, 'loss': 0.6899237036705017}
# {'epoch': 16, 'batch': 60, 'loss': 0.7253921627998352}
# {'epoch': 16, 'batch': 90, 'loss': 0.747697114944458}
# {'epoch': 16, 'batch': 120, 'loss': 0.7609129548072815}
# {'epoch': 16, 'batch': 150, 'loss': 0.7360632419586182}
# {'epoch': 17, 'batch': 0, 'loss': 0.6515796780586243}
# {'epoch': 17, 'batch': 30, 'loss': 0.6548432111740112}
# {'epoch': 17, 'batch': 60, 'loss': 0.679908275604248}
# {'epoch': 17, 'batch': 90, 'loss': 0.6983065009117126}
# {'epoch': 17, 'batch': 120, 'loss': 0.7144256830215454}
# {'epoch': 17, 'batch': 150, 'loss': 0.7224727869033813}
# {'epoch': 18, 'batch': 0, 'loss': 0.6415821313858032}
# {'epoch': 18, 'batch': 30, 'loss': 0.6539833545684814}
# {'epoch': 18, 'batch': 60, 'loss': 0.6537528038024902}
# {'epoch': 18, 'batch': 90, 'loss': 0.6670424938201904}
# {'epoch': 18, 'batch': 120, 'loss': 0.6771054863929749}
# {'epoch': 18, 'batch': 150, 'loss': 0.6770839691162109}
# {'epoch': 19, 'batch': 0, 'loss': 0.5707632303237915}
# {'epoch': 19, 'batch': 30, 'loss': 0.584467887878418}
# {'epoch': 19, 'batch': 60, 'loss': 0.6097362041473389}
# {'epoch': 19, 'batch': 90, 'loss': 0.6200443506240845}
# {'epoch': 19, 'batch': 120, 'loss': 0.66621994972229}
# {'epoch': 19, 'batch': 150, 'loss': 0.6567755341529846}
# {'epoch': 20, 'batch': 0, 'loss': 0.5521789789199829}
# {'epoch': 20, 'batch': 30, 'loss': 0.5807116031646729}
# {'epoch': 20, 'batch': 60, 'loss': 0.5834097266197205}
# {'epoch': 20, 'batch': 90, 'loss': 0.6127722263336182}
# {'epoch': 20, 'batch': 120, 'loss': 0.6198364496231079}
# {'epoch': 20, 'batch': 150, 'loss': 0.6345457434654236}
# {'epoch': 21, 'batch': 0, 'loss': 0.5333366990089417}
# {'epoch': 21, 'batch': 30, 'loss': 0.547031819820404}
# {'epoch': 21, 'batch': 60, 'loss': 0.56923508644104}
# {'epoch': 21, 'batch': 90, 'loss': 0.5782979130744934}
# {'epoch': 21, 'batch': 120, 'loss': 0.6013929843902588}
# {'epoch': 21, 'batch': 150, 'loss': 0.5947010517120361}
# {'epoch': 22, 'batch': 0, 'loss': 0.4976212978363037}
# {'epoch': 22, 'batch': 30, 'loss': 0.5217704176902771}
# {'epoch': 22, 'batch': 60, 'loss': 0.524466872215271}
# {'epoch': 22, 'batch': 90, 'loss': 0.5473151206970215}
# {'epoch': 22, 'batch': 120, 'loss': 0.5707570910453796}
# {'epoch': 22, 'batch': 150, 'loss': 0.5976394414901733}
# {'epoch': 23, 'batch': 0, 'loss': 0.48312950134277344}
# {'epoch': 23, 'batch': 30, 'loss': 0.4864043891429901}
# {'epoch': 23, 'batch': 60, 'loss': 0.5206716656684875}
# {'epoch': 23, 'batch': 90, 'loss': 0.5247011184692383}
# {'epoch': 23, 'batch': 120, 'loss': 0.5295442938804626}
# {'epoch': 23, 'batch': 150, 'loss': 0.5578033924102783}
# {'epoch': 24, 'batch': 0, 'loss': 0.46872463822364807}
# {'epoch': 24, 'batch': 30, 'loss': 0.4689628481864929}
# {'epoch': 24, 'batch': 60, 'loss': 0.49506238102912903}
# {'epoch': 24, 'batch': 90, 'loss': 0.5169088244438171}
# {'epoch': 24, 'batch': 120, 'loss': 0.5222221612930298}
# {'epoch': 24, 'batch': 150, 'loss': 0.5484386682510376}
# {'epoch': 25, 'batch': 0, 'loss': 0.4510784149169922}
# {'epoch': 25, 'batch': 30, 'loss': 0.46730244159698486}
# {'epoch': 25, 'batch': 60, 'loss': 0.4812670052051544}
# {'epoch': 25, 'batch': 90, 'loss': 0.5061848759651184}
# {'epoch': 25, 'batch': 120, 'loss': 0.5248150825500488}
# {'epoch': 25, 'batch': 150, 'loss': 0.5271075367927551}
# {'epoch': 26, 'batch': 0, 'loss': 0.4347512125968933}
# {'epoch': 26, 'batch': 30, 'loss': 0.44606631994247437}
# {'epoch': 26, 'batch': 60, 'loss': 0.4699062705039978}
# {'epoch': 26, 'batch': 90, 'loss': 0.4788224697113037}
# {'epoch': 26, 'batch': 120, 'loss': 0.4950498640537262}
# {'epoch': 26, 'batch': 150, 'loss': 0.5074264407157898}
# {'epoch': 27, 'batch': 0, 'loss': 0.4255391061306}
# {'epoch': 27, 'batch': 30, 'loss': 0.443785160779953}
# {'epoch': 27, 'batch': 60, 'loss': 0.4450153708457947}
# {'epoch': 27, 'batch': 90, 'loss': 0.4585719406604767}
# {'epoch': 27, 'batch': 120, 'loss': 0.46957987546920776}
# {'epoch': 27, 'batch': 150, 'loss': 0.4962522089481354}
# {'epoch': 28, 'batch': 0, 'loss': 0.4180452227592468}
# {'epoch': 28, 'batch': 30, 'loss': 0.4405176043510437}
# {'epoch': 28, 'batch': 60, 'loss': 0.43281883001327515}
# {'epoch': 28, 'batch': 90, 'loss': 0.4460814595222473}
# {'epoch': 28, 'batch': 120, 'loss': 0.4620637893676758}
# {'epoch': 28, 'batch': 150, 'loss': 0.4893776774406433}
# {'epoch': 29, 'batch': 0, 'loss': 0.394755095243454}
# {'epoch': 29, 'batch': 30, 'loss': 0.396040678024292}
# {'epoch': 29, 'batch': 60, 'loss': 0.4256021976470947}
# {'epoch': 29, 'batch': 90, 'loss': 0.4473986327648163}
# {'epoch': 29, 'batch': 120, 'loss': 0.45487475395202637}
# {'epoch': 29, 'batch': 150, 'loss': 0.4945172071456909}

# %%
#Visualize the loss evolution during training
plt.plot(losses)
plt.title('model loss')
plt.show()

# %% [markdown]
# We can observe in the plots  GRU overfitted. Even thought the LSTM model works very well; it achieves a very low loss and in the plot we can see how the loss becomes smaller at the time the epochs grow. Also with the simpler RNN model we achieve low loss values and without overfitting. At the end the best model in this situation is the LSTM because is the one that achieves the lowest loss scores and also without overfitting as the plot shows.

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 4:** Train your best model on a different dataset. Use the 'inaugural' corpus of the [NLTK](https://www.nltk.org/) library. Once trained generate some text with as we did for the model trained on the Shakespeare dataset. Compare the generated texts with both models using the smae "seed" (input) text. What differences do you appreciate? Why are they different?
#
# </span>
#
# The Natural Language Toolkit, or more commonly NLTK, is a suite of datasets, libraries and models for symbolic and statistical natural language processing (NLP). The Inaugural Address Corpus contains the US presidential inaugural addresses from 1789 to 2017. The following code loads the 'inaugural' corpus:

# %%
import nltk
nltk.download('inaugural')

inaugural = nltk.corpus.inaugural
text = inaugural.raw()

print(f'Length of text: {len(text)} characters')
# Out:
# Length of text: 807276 characters
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!

# %%
class DatasetFromTextFile():
    def __init__(self, text, sequence_length):
        self.text = text
        self.sequence_length = sequence_length
        
        # The whole sequence of characters in the text file (including characters like the end of line character '\n', punctuation marks, etc.)
        self.chars = text
        # The list of unique characters (our vocabulary)
        self.uniq_chars = self.get_uniq_chars()

        # A dictionary with indices as keys and characters as values
        self.index_to_char = {index: char for index, char in enumerate(self.uniq_chars)}
        # A dictionary with characters as keys and indices as values
        self.char_to_index = {char: index for index, char in enumerate(self.uniq_chars)}

        # The whole sequence of character indexes
        # We want to vectorize our text using one-hot vectors at character level
        # But instead of using the one-hot vector we just keep the index of the 1 value
        self.chars_indices = [self.char_to_index[w] for w in self.chars]

        # Split the sequence into chunks of `sequence_length` characters
        # `x` is the input to the model and `y` is the output of the model
        # `y` is the same seuqence as `x` but one character shifted to the right.
        self.x, self.y = self.get_data()

    def load_chars(self):
        print(f'Length of text: {len(self.text)} characters')
        return self.text

    def get_uniq_chars(self):
        char_counts = Counter(self.chars)
        uniq_chars = sorted(char_counts, key=char_counts.get, reverse=True)
        print(f'Unique characters (vocabulary size): {len(uniq_chars)}')
        return uniq_chars

    def get_data(self):
        x,y = [], []
        for index in range(0, len(self.chars_indices)-self.sequence_length, self.sequence_length):
            x.append(np.array(self.chars_indices[index:index+self.sequence_length]))
            y.append(np.array(self.chars_indices[index+1:index+self.sequence_length+1]))
        
        return  torch.from_numpy(np.array(x)), torch.from_numpy(np.array(y)).long()
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        assert ((idx >= 0) & (idx < len(self.y))), "Dataset index out of range"
        return self.x[idx], self.y[idx]

# %%
# Create the dataset
sequence_length = 100
InaguralDataset = DatasetFromTextFile(text, sequence_length)

print(f'We have {InaguralDataset.x.shape[0]} input sequence samples of length {InaguralDataset.x.shape[1]} \
and {InaguralDataset.y.shape[0]} label sequences of length {InaguralDataset.y.shape[1]}')

# Create the Torch DataLoader
batch_size = 64
train_loader = DataLoader(InaguralDataset, shuffle=True, batch_size=batch_size, drop_last=True)
# Out:
# Unique characters (vocabulary size): 85
# We have 8072 input sequence samples of length 100 and 8072 label sequences of length 100

# %%
input_dim = len(InaguralDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(InaguralDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

model_lstm_Inagural = Model_LSTM(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(model_lstm_Inagural)
# Out:
# Model_LSTM(
#   (embedding): Embedding(85, 300)
#   (lstm): LSTM(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=85, bias=True)
# )

# %%
num_epochs = 25
print('TRAINING MODEL: ', model_lstm_Inagural, '\n')
losses = train_LSTM(train_loader, model_lstm_Inagural, batch_size, sequence_length, num_epochs)
# Out:
# TRAINING MODEL:  Model_LSTM(
#   (embedding): Embedding(85, 300)
#   (lstm): LSTM(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=85, bias=True)
# )
#
# {'epoch': 0, 'batch': 0, 'loss': 4.44428825378418}
# {'epoch': 0, 'batch': 30, 'loss': 2.3254542350769043}
# {'epoch': 0, 'batch': 60, 'loss': 1.8869378566741943}
# {'epoch': 0, 'batch': 90, 'loss': 1.6665244102478027}
# {'epoch': 0, 'batch': 120, 'loss': 1.5620783567428589}
# {'epoch': 1, 'batch': 0, 'loss': 1.4929008483886719}
# {'epoch': 1, 'batch': 30, 'loss': 1.3826158046722412}
# {'epoch': 1, 'batch': 60, 'loss': 1.3133703470230103}
# {'epoch': 1, 'batch': 90, 'loss': 1.3099371194839478}
# {'epoch': 1, 'batch': 120, 'loss': 1.2765549421310425}
# {'epoch': 2, 'batch': 0, 'loss': 1.2297908067703247}
# {'epoch': 2, 'batch': 30, 'loss': 1.271714448928833}
# {'epoch': 2, 'batch': 60, 'loss': 1.2407556772232056}
# {'epoch': 2, 'batch': 90, 'loss': 1.2124624252319336}
# {'epoch': 2, 'batch': 120, 'loss': 1.1931939125061035}
# {'epoch': 3, 'batch': 0, 'loss': 1.1851750612258911}
# {'epoch': 3, 'batch': 30, 'loss': 1.1874357461929321}
# {'epoch': 3, 'batch': 60, 'loss': 1.1790425777435303}
# {'epoch': 3, 'batch': 90, 'loss': 1.1606321334838867}
# {'epoch': 3, 'batch': 120, 'loss': 1.1364251375198364}
# {'epoch': 4, 'batch': 0, 'loss': 1.1366562843322754}
# {'epoch': 4, 'batch': 30, 'loss': 1.128669261932373}
# {'epoch': 4, 'batch': 60, 'loss': 1.1032705307006836}
# {'epoch': 4, 'batch': 90, 'loss': 1.0896239280700684}
# {'epoch': 4, 'batch': 120, 'loss': 1.1122263669967651}
# {'epoch': 5, 'batch': 0, 'loss': 1.0320852994918823}
# {'epoch': 5, 'batch': 30, 'loss': 1.0438474416732788}
# {'epoch': 5, 'batch': 60, 'loss': 1.0825340747833252}
# {'epoch': 5, 'batch': 90, 'loss': 1.100317120552063}
# {'epoch': 5, 'batch': 120, 'loss': 1.0667420625686646}
# {'epoch': 6, 'batch': 0, 'loss': 1.0475941896438599}
# {'epoch': 6, 'batch': 30, 'loss': 1.0440620183944702}
# {'epoch': 6, 'batch': 60, 'loss': 1.0665282011032104}
# {'epoch': 6, 'batch': 90, 'loss': 1.0412482023239136}
# {'epoch': 6, 'batch': 120, 'loss': 1.0520881414413452}
# {'epoch': 7, 'batch': 0, 'loss': 1.0019276142120361}
# {'epoch': 7, 'batch': 30, 'loss': 1.0122159719467163}
# {'epoch': 7, 'batch': 60, 'loss': 1.0278518199920654}
# {'epoch': 7, 'batch': 90, 'loss': 1.0439026355743408}
# {'epoch': 7, 'batch': 120, 'loss': 1.0408903360366821}
# {'epoch': 8, 'batch': 0, 'loss': 0.9871441721916199}
# {'epoch': 8, 'batch': 30, 'loss': 0.971602201461792}
# {'epoch': 8, 'batch': 60, 'loss': 0.986106276512146}
# {'epoch': 8, 'batch': 90, 'loss': 1.0180896520614624}
# {'epoch': 8, 'batch': 120, 'loss': 0.9828605055809021}
# {'epoch': 9, 'batch': 0, 'loss': 0.9492021203041077}
# {'epoch': 9, 'batch': 30, 'loss': 0.9678676724433899}
# {'epoch': 9, 'batch': 60, 'loss': 0.9643709659576416}
# {'epoch': 9, 'batch': 90, 'loss': 0.9885371327400208}
# {'epoch': 9, 'batch': 120, 'loss': 0.9577468633651733}
# {'epoch': 10, 'batch': 0, 'loss': 0.9216177463531494}
# {'epoch': 10, 'batch': 30, 'loss': 0.9169921875}
# {'epoch': 10, 'batch': 60, 'loss': 0.9352628588676453}
# {'epoch': 10, 'batch': 90, 'loss': 0.9707750082015991}
# {'epoch': 10, 'batch': 120, 'loss': 0.9174736738204956}
# {'epoch': 11, 'batch': 0, 'loss': 0.8898857831954956}
# {'epoch': 11, 'batch': 30, 'loss': 0.8908202648162842}
# {'epoch': 11, 'batch': 60, 'loss': 0.9259421825408936}
# {'epoch': 11, 'batch': 90, 'loss': 0.9283839464187622}
# {'epoch': 11, 'batch': 120, 'loss': 0.9535085558891296}
# {'epoch': 12, 'batch': 0, 'loss': 0.8615890741348267}
# {'epoch': 12, 'batch': 30, 'loss': 0.8759174346923828}
# {'epoch': 12, 'batch': 60, 'loss': 0.8730639815330505}
# {'epoch': 12, 'batch': 90, 'loss': 0.874619722366333}
# {'epoch': 12, 'batch': 120, 'loss': 0.8922301530838013}
# {'epoch': 13, 'batch': 0, 'loss': 0.8078904151916504}
# {'epoch': 13, 'batch': 30, 'loss': 0.8207660913467407}
# {'epoch': 13, 'batch': 60, 'loss': 0.8439157009124756}
# {'epoch': 13, 'batch': 90, 'loss': 0.8563816547393799}
# {'epoch': 13, 'batch': 120, 'loss': 0.8438407182693481}
# {'epoch': 14, 'batch': 0, 'loss': 0.7831332683563232}
# {'epoch': 14, 'batch': 30, 'loss': 0.7763574123382568}
# {'epoch': 14, 'batch': 60, 'loss': 0.8438475728034973}
# {'epoch': 14, 'batch': 90, 'loss': 0.8076239228248596}
# {'epoch': 14, 'batch': 120, 'loss': 0.8192839026451111}
# {'epoch': 15, 'batch': 0, 'loss': 0.7551615238189697}
# {'epoch': 15, 'batch': 30, 'loss': 0.7505251169204712}
# {'epoch': 15, 'batch': 60, 'loss': 0.7811952829360962}
# {'epoch': 15, 'batch': 90, 'loss': 0.7995755076408386}
# {'epoch': 15, 'batch': 120, 'loss': 0.8182316422462463}
# {'epoch': 16, 'batch': 0, 'loss': 0.7325583100318909}
# {'epoch': 16, 'batch': 30, 'loss': 0.7244616746902466}
# {'epoch': 16, 'batch': 60, 'loss': 0.7414896488189697}
# {'epoch': 16, 'batch': 90, 'loss': 0.7309455871582031}
# {'epoch': 16, 'batch': 120, 'loss': 0.7692947387695312}
# {'epoch': 17, 'batch': 0, 'loss': 0.6859177350997925}
# {'epoch': 17, 'batch': 30, 'loss': 0.6898546814918518}
# {'epoch': 17, 'batch': 60, 'loss': 0.6955829858779907}
# {'epoch': 17, 'batch': 90, 'loss': 0.7250973582267761}
# {'epoch': 17, 'batch': 120, 'loss': 0.7438204288482666}
# {'epoch': 18, 'batch': 0, 'loss': 0.6479941606521606}
# {'epoch': 18, 'batch': 30, 'loss': 0.655992329120636}
# {'epoch': 18, 'batch': 60, 'loss': 0.6572766900062561}
# {'epoch': 18, 'batch': 90, 'loss': 0.683664083480835}
# {'epoch': 18, 'batch': 120, 'loss': 0.7184178233146667}
# {'epoch': 19, 'batch': 0, 'loss': 0.613802969455719}
# {'epoch': 19, 'batch': 30, 'loss': 0.6178081631660461}
# {'epoch': 19, 'batch': 60, 'loss': 0.6196626424789429}
# {'epoch': 19, 'batch': 90, 'loss': 0.6777624487876892}
# {'epoch': 19, 'batch': 120, 'loss': 0.6630795001983643}
# {'epoch': 20, 'batch': 0, 'loss': 0.5891512036323547}
# {'epoch': 20, 'batch': 30, 'loss': 0.5652455687522888}
# {'epoch': 20, 'batch': 60, 'loss': 0.5944514274597168}
# {'epoch': 20, 'batch': 90, 'loss': 0.6158095598220825}
# {'epoch': 20, 'batch': 120, 'loss': 0.6243300437927246}
# {'epoch': 21, 'batch': 0, 'loss': 0.5279627442359924}
# {'epoch': 21, 'batch': 30, 'loss': 0.5445526838302612}
# {'epoch': 21, 'batch': 60, 'loss': 0.5569527745246887}
# {'epoch': 21, 'batch': 90, 'loss': 0.5773576498031616}
# {'epoch': 21, 'batch': 120, 'loss': 0.6175011396408081}
# {'epoch': 22, 'batch': 0, 'loss': 0.49914464354515076}
# {'epoch': 22, 'batch': 30, 'loss': 0.5107378363609314}
# {'epoch': 22, 'batch': 60, 'loss': 0.532377302646637}
# {'epoch': 22, 'batch': 90, 'loss': 0.5392664670944214}
# {'epoch': 22, 'batch': 120, 'loss': 0.5759082436561584}
# {'epoch': 23, 'batch': 0, 'loss': 0.4686657786369324}
# {'epoch': 23, 'batch': 30, 'loss': 0.4926328957080841}
# {'epoch': 23, 'batch': 60, 'loss': 0.5097478032112122}
# {'epoch': 23, 'batch': 90, 'loss': 0.5245665907859802}
# {'epoch': 23, 'batch': 120, 'loss': 0.5437426567077637}
# {'epoch': 24, 'batch': 0, 'loss': 0.45166531205177307}
# {'epoch': 24, 'batch': 30, 'loss': 0.43946242332458496}
# {'epoch': 24, 'batch': 60, 'loss': 0.4872465431690216}
# {'epoch': 24, 'batch': 90, 'loss': 0.48971328139305115}
# {'epoch': 24, 'batch': 120, 'loss': 0.5085532665252686}

# %%
# Visualize the loss evolution during training
plt.plot(losses)
plt.title('model loss')
plt.show()

# %%
def predict_LSTM(dataset, model, text, next_chars=1000):
    model.eval()

    chars = [char for char in text]
    state = model.init_hidden(1)
    state = (state[0].to(device), state[1].to(device)) # modify the hidden state initialization to account for LSTM's cell state

    # we start by feeding all the input characters to our model
    x = torch.tensor([dataset.char_to_index[char] for char in chars])
    x = x.unsqueeze(0) # create a batch of 1
    x = x.to(device)

    for i in range(0, next_chars):
        
        y_pred, state = model(x, state)

        last_char_logits = y_pred[0][-1]
        p = torch.nn.functional.softmax(last_char_logits, dim=0).detach().cpu().numpy()
        char_index = np.random.choice(len(last_char_logits), p=p)
        chars.append(dataset.index_to_char[char_index])

        # the output of the model (a single character index) becomes the input at next iteration
        x = torch.tensor([[char_index]])
        x = x.to(device)

    return chars

# %%
predicted = predict_LSTM(InaguralDataset, model_lstm_Inagural,'ROMEO:')
print(''.join(predicted))
# Out:
# ROMEO:
# I there has been something defined by the Federal Government can do for it in the precepted for its injury, and to take cut with us the Penetive upon which I am untoubted the rights of the people, and generally depart. We must kove our strongest that a general revolution throughout a perfection or the individual to secure the largest income with the interior quality of social order and over laws. If corruption, arpens of runawal life, nor in order, to prevent it, and for a common sense, either and unreasonable, considered thought, virtue, and conservative American relationship, but when we recognize the energies, but preserved, and, with constitutional can is thankful for the freedom of the people. And for our way must be weakened and the prevailing passion of our Federal Union. And that lower knows that tyme are not just my goals that we shall have far from the people of the world want peace.
#
# Together, we Indecking war out of the power which reflect our political action the principl
